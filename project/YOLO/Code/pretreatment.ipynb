# %%
import json
from pathlib import Path
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
print(cv2.__version__)
# Out:
# 4.5.4-dev

# %% [markdown]
# # 고려 사항
#  1. json 파일 box 좌표가 어떤 걸 나타내는지 확인 (ai hub 데이터는 center_x, center_y, w, h 를 나타냄)
#  2. json 파일에 box 좌표가 몇개 있는지 확인
#  3. json 파일 내에 w, h, img_w, img_h 중 0값이 있는지 확인
#  3. class type 은 int로 변환 나머지 좌표값 및 w,h 는 float 형 유지

# %% [markdown]
# # 데이터 경로 설정

# %%
data_path = Path('D:\\Data\\YOLO\\Road_Obstacles\\2020-02-061.도로장애물표면인지(수도권)_sample')
label = data_path/ '061.도로장애물-표면인지영상(수도권)_샘플_라벨링데이터'
image = data_path/ '061.도로장애물-표면인지영상(수도권)_샘플_원천데이터'
txt = data_path/'061.도로장애물-표면인지영상(수도권)_샘플_txt데이터'

# %% [markdown]
# # 데이터 확인

# %%
data_json = label.glob('*.json') ## glob 함수는 generator을 반환해 주는 거여서 data_json을 계속해서 초기화 시켜야함
for j in data_json:
    with open(str(j)) as f:
        json_data = json.load(f)
        print(json.dumps(json_data ,indent = '\t')) ## '\t'를 통해 들여쓰기 설정
# Out:
# {
# 	"info": {
# 		"description": "V0F_HY_1942_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_39083_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_1942_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_39083.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				778.5094900248621,
# 				299.2177551391668,
# 				46.57085683099865,
# 				108.6653326056637
# 			],
# 			"category_id": 4,
# 			"area": 5060.637647271214,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				941.8590253825064,
# 				273.954187671354,
# 				77.54488370036256,
# 				174.3344830635889
# 			],
# 			"category_id": 4,
# 			"area": 13518.747214128827,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_6095_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_15040_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_6095_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_15040.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				902.3179710935368,
# 				275.1749840923552,
# 				69.2300699936369,
# 				172.2025270429961
# 			],
# 			"category_id": 4,
# 			"area": 11921.593000267772,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_1201_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_60941_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_1201_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_60941.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1046.5078060805258,
# 				242.9580936729663,
# 				96.7625308134759,
# 				215.61216105176663
# 			],
# 			"category_id": 4,
# 			"area": 20863.178377531698,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_1799_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_10496_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_1799_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_10496.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				873.2361516034983,
# 				283.6151603498542,
# 				64.68415937803707,
# 				156.73469387755102
# 			],
# 			"category_id": 4,
# 			"area": 10138.251918843362,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_6279_20210129_133533_E_CH1_Seoul_Sun_Industrialroads_Day_43342_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_6279_20210129_133533_E_CH1_Seoul_Sun_Industrialroads_Day_43342.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				732.6724975704567,
# 				318.44509232264335,
# 				34.829931972789154,
# 				85.83090379008746
# 			],
# 			"category_id": 4,
# 			"area": 2989.484540171757,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_7007_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_53399_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_7007_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_53399.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				429.2547660311958,
# 				633.8994800693241,
# 				197.15771230502605,
# 				42.42634315424607
# 			],
# 			"category_id": 10,
# 			"area": 8364.680757759159,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_6632_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_51305_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_6632_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_51305.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				986.5384615384615,
# 				260.8974358974359,
# 				88.46153846153845,
# 				205.76923076923072
# 			],
# 			"category_id": 4,
# 			"area": 18202.662721893485,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_7024_20210129_133333_E_CH1_Seoul_Sun_Industrialroads_Day_49051_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_7024_20210129_133333_E_CH1_Seoul_Sun_Industrialroads_Day_49051.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1047.2888642351963,
# 				639.9112467064208,
# 				161.53099431424198,
# 				28.40105394536124
# 			],
# 			"category_id": 10,
# 			"area": 4587.650483366627,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1124.8114558472553,
# 				233.39379474940336,
# 				88.59188544152744,
# 				188.18138424821
# 			],
# 			"category_id": 4,
# 			"area": 16671.343635545476,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				764.6944370743787,
# 				316.9717873883435,
# 				25.47094720084897,
# 				67.35650482002296
# 			],
# 			"category_id": 4,
# 			"area": 1715.6339779045338,
# 			"is_crowd": 0,
# 			"id": 3
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_8250_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_29343_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_8250_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_29343.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1120.120754716981,
# 				226.05283018867925,
# 				113.02641509433964,
# 				281.11698113207547
# 			],
# 			"category_id": 4,
# 			"area": 31773.644599501607,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_9052_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_08734_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_9052_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_08734.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				136.4102564102564,
# 				599.4871794871794,
# 				220.5128205128205,
# 				38.46153846153857
# 			],
# 			"category_id": 10,
# 			"area": 8481.262327416196,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0000_20160212_013015_E_CH1_Seoul_Sun_Mainroad_Sunset_32495_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0000_20160212_013015_E_CH1_Seoul_Sun_Mainroad_Sunset_32495.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				951.6389548693588,
# 				396.2628661916073,
# 				214.85352335708623,
# 				52.69992082343623
# 			],
# 			"category_id": 10,
# 			"area": 11322.763669554752,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0000_20160212_014740_E_CH0_Seoul_Sun_Mainroad_Sunset_25300_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0000_20160212_014740_E_CH0_Seoul_Sun_Mainroad_Sunset_25300.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1082.5699882012227,
# 				621.2592513139547,
# 				197.4300117987773,
# 				53.54499624584366
# 			],
# 			"category_id": 10,
# 			"area": 10571.389240582399,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0002_20160212_014348_E_CH1_Seoul_Sun_Mainroad_Sunset_47352_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0002_20160212_014348_E_CH1_Seoul_Sun_Mainroad_Sunset_47352.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				21.041864542997004,
# 				316.0955651347994,
# 				238.94206181047707,
# 				45.82450500474903
# 			],
# 			"category_id": 10,
# 			"area": 10949.401707279258,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0001_20160212_014340_N_CH2_Seoul_Sun_Mainroad_Day_70012_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0001_20160212_014340_N_CH2_Seoul_Sun_Mainroad_Day_70012.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				334.33333717592114,
# 				614.9752023987708,
# 				407.4626865671641,
# 				79.01976786238798
# 			],
# 			"category_id": 10,
# 			"area": 32197.60690512226,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0000_20160212_025030_N_CH1_Seoul_Snow_Frontback_Day_14973_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0000_20160212_025030_N_CH1_Seoul_Snow_Frontback_Day_14973.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				127.5,
# 				166.5,
# 				49,
# 				38
# 			],
# 			"category_id": 6,
# 			"area": 1862,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				180.1282051282051,
# 				146.7948717948718,
# 				91.66666666666666,
# 				48.7179487179487
# 			],
# 			"category_id": 3,
# 			"area": 4465.811965811964,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V0F_HY_9185_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_30356_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V0F_HY_9185_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_30356.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				792.2619047619048,
# 				300.59523809523813,
# 				48.214285714285666,
# 				123.21428571428572
# 			],
# 			"category_id": 4,
# 			"area": 5940.688775510199,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0004_20160212_022609_E_CH0_Seoul_Sun_Frontback_Day_87097_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0004_20160212_022609_E_CH0_Seoul_Sun_Frontback_Day_87097.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				395.94129371262915,
# 				365.2835658633811,
# 				23.482514948360233,
# 				51.85722051096212
# 			],
# 			"category_id": 5,
# 			"area": 1217.7379558290809,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				419.7499547019388,
# 				361.6959594129371,
# 				22.504076825511845,
# 				47.29117593766989
# 			],
# 			"category_id": 5,
# 			"area": 1064.2442564701205,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0004_20160212_015840_E_CH0_Seoul_Sun_Mainroad_Sunset_81466_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0004_20160212_015840_E_CH0_Seoul_Sun_Mainroad_Sunset_81466.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				415.6913183279743,
# 				201.67202572347267,
# 				137.87781350482317,
# 				288.1028938906752
# 			],
# 			"category_id": 2,
# 			"area": 39722.997074058374,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				517.556270096463,
# 				205.7877813504823,
# 				73.05466237942119,
# 				232.540192926045
# 			],
# 			"category_id": 2,
# 			"area": 16988.145283857684,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1249.1318327974277,
# 				256.20578778135047,
# 				17.49196141479092,
# 				49.389067524115774
# 			],
# 			"category_id": 2,
# 			"area": 863.9116634443365,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1267.652733118971,
# 				256.20578778135047,
# 				9.260450160771825,
# 				49.389067524115774
# 			],
# 			"category_id": 2,
# 			"area": 457.3649982940684,
# 			"is_crowd": 0,
# 			"id": 4
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0005_20160212_014433_E_CH0_Seoul_Sun_Mainroad_Day_39936_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0005_20160212_014433_E_CH0_Seoul_Sun_Mainroad_Day_39936.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				30,
# 				201.9047619047619,
# 				164.28571428571428,
# 				283.80952380952374
# 			],
# 			"category_id": 2,
# 			"area": 46625.85034013604,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				946.7573221757322,
# 				208.2635983263598,
# 				19.351464435146458,
# 				47.280334728033466
# 			],
# 			"category_id": 2,
# 			"area": 914.9437159713596,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0001_20160212_013833_E_CH1_Seoul_Sun_Frontback_Day_38133_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0001_20160212_013833_E_CH1_Seoul_Sun_Frontback_Day_38133.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				783.3333333333333,
# 				323.7179487179487,
# 				173.71794871794873,
# 				33.974358974359006
# 			],
# 			"category_id": 10,
# 			"area": 5901.955950032879,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				341.66666666666663,
# 				363.46153846153845,
# 				237.1794871794872,
# 				73.71794871794873
# 			],
# 			"category_id": 10,
# 			"area": 17484.385272846815,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				650.6410256410256,
# 				58.97435897435897,
# 				57.05128205128199,
# 				140.817232181857
# 			],
# 			"category_id": 2,
# 			"area": 8033.803630887987,
# 			"is_crowd": 0,
# 			"id": 3
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0004_20201208_150220_E_CH1_Seoul_Sun_Mainroad_Day_75586_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0004_20201208_150220_E_CH1_Seoul_Sun_Mainroad_Day_75586.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1034.5,
# 				0,
# 				95,
# 				245.5
# 			],
# 			"category_id": 2,
# 			"area": 23322.5,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				207.5,
# 				16.5,
# 				44,
# 				81
# 			],
# 			"category_id": 2,
# 			"area": 3564,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0002_20160212_022518_E_CH0_Seoul_Cloud_Mainroad_Day_05715_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0002_20160212_022518_E_CH0_Seoul_Cloud_Mainroad_Day_05715.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				434.9075491697091,
# 				587.1628783417736,
# 				179.38994229183845,
# 				40.70191967966082
# 			],
# 			"category_id": 10,
# 			"area": 7301.515022501398,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				977.4092562822574,
# 				368.2206616465014,
# 				87.18165665453932,
# 				14.620526271258145
# 			],
# 			"category_id": 10,
# 			"area": 1274.6417014894996,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0007_20160212_023630_N_CH0_Seoul_Snow_Mainroad_Day_20813_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0007_20160212_023630_N_CH0_Seoul_Snow_Mainroad_Day_20813.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				729.5094339622641,
# 				247.2452830188679,
# 				46.18867924528297,
# 				130.41509433962267
# 			],
# 			"category_id": 2,
# 			"area": 6023.70096119615,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				195.62264150943395,
# 				461.61361509372114,
# 				89.66037735849056,
# 				17.60870037847178
# 			],
# 			"category_id": 10,
# 			"area": 1578.8027207263756,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				991.6981132075472,
# 				412.9811320754717,
# 				70.64150943396226,
# 				127.69811320754718
# 			],
# 			"category_id": 3,
# 			"area": 9020.787468850125,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				964.5283018867924,
# 				411.62264150943395,
# 				29.88679245283015,
# 				118.18867924528296
# 			],
# 			"category_id": 3,
# 			"area": 3532.280526877886,
# 			"is_crowd": 0,
# 			"id": 4
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0006_20160212_024330_N_CH0_Seoul_Snow_Frontback_Day_28761_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0006_20160212_024330_N_CH0_Seoul_Snow_Frontback_Day_28761.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				223.48484848484847,
# 				384.8484848484848,
# 				51.51515151515153,
# 				119.69696969696967
# 			],
# 			"category_id": 5,
# 			"area": 6166.207529843894,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				312.8787878787879,
# 				359.09090909090907,
# 				37.121212121212125,
# 				90.15151515151518
# 			],
# 			"category_id": 5,
# 			"area": 3346.533516988064,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				362.8787878787879,
# 				344.6969696969697,
# 				28.787878787878753,
# 				77.27272727272725
# 			],
# 			"category_id": 5,
# 			"area": 2224.5179063360847,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				399.24242424242425,
# 				333.3333333333333,
# 				29.545454545454504,
# 				64.39393939393938
# 			],
# 			"category_id": 5,
# 			"area": 1902.548209366388,
# 			"is_crowd": 0,
# 			"id": 4
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				430.30303030303025,
# 				326.5151515151515,
# 				21.969696969696997,
# 				61.363636363636374
# 			],
# 			"category_id": 5,
# 			"area": 1348.1404958677706,
# 			"is_crowd": 0,
# 			"id": 5
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				456.06060606060606,
# 				315.1515151515151,
# 				19.69696969696969,
# 				46.969696969697
# 			],
# 			"category_id": 5,
# 			"area": 925.1606978879707,
# 			"is_crowd": 0,
# 			"id": 6
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				483.3333333333333,
# 				312.1212121212121,
# 				15.151515151515127,
# 				36.36363636363632
# 			],
# 			"category_id": 5,
# 			"area": 550.9641873278221,
# 			"is_crowd": 0,
# 			"id": 7
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				499.2424242424242,
# 				315.9090909090909,
# 				9.848484848484873,
# 				26.51515151515156
# 			],
# 			"category_id": 5,
# 			"area": 261.13406795225086,
# 			"is_crowd": 0,
# 			"id": 8
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				506.06060606060606,
# 				305.3030303030303,
# 				12.878787878787818,
# 				32.575757575757564
# 			],
# 			"category_id": 5,
# 			"area": 419.53627180899696,
# 			"is_crowd": 0,
# 			"id": 9
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				523.4848484848485,
# 				295.45454545454544,
# 				9.090909090909008,
# 				25.75757575757575
# 			],
# 			"category_id": 5,
# 			"area": 234.15977961432287,
# 			"is_crowd": 0,
# 			"id": 10
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				534.0909090909091,
# 				294.6969696969697,
# 				12.121212121212013,
# 				22.727272727272748
# 			],
# 			"category_id": 5,
# 			"area": 275.4820936639096,
# 			"is_crowd": 0,
# 			"id": 11
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				546.6666666666667,
# 				300,
# 				5,
# 				17.08333333333337
# 			],
# 			"category_id": 5,
# 			"area": 85.41666666666686,
# 			"is_crowd": 0,
# 			"id": 12
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				555.4166666666667,
# 				297.08333333333337,
# 				5.416666666666629,
# 				18.75
# 			],
# 			"category_id": 5,
# 			"area": 101.56249999999929,
# 			"is_crowd": 0,
# 			"id": 13
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				569.1666666666667,
# 				299.1666666666667,
# 				8.333333333333258,
# 				16.666666666666686
# 			],
# 			"category_id": 5,
# 			"area": 138.88888888888778,
# 			"is_crowd": 0,
# 			"id": 14
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				587.9166666666667,
# 				297.5,
# 				10.416666666666629,
# 				16.25
# 			],
# 			"category_id": 5,
# 			"area": 169.27083333333272,
# 			"is_crowd": 0,
# 			"id": 15
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				603.75,
# 				297.08333333333337,
# 				5.833333333333371,
# 				15.416666666666629
# 			],
# 			"category_id": 5,
# 			"area": 89.93055555555591,
# 			"is_crowd": 0,
# 			"id": 16
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				617.9166666666667,
# 				298.75,
# 				8.75,
# 				13.75
# 			],
# 			"category_id": 5,
# 			"area": 120.3125,
# 			"is_crowd": 0,
# 			"id": 17
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				633.3333333333334,
# 				295,
# 				6.25,
# 				14.583333333333371
# 			],
# 			"category_id": 5,
# 			"area": 91.14583333333357,
# 			"is_crowd": 0,
# 			"id": 18
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				647.5,
# 				294.1666666666667,
# 				6.6666666666667425,
# 				14.166666666666686
# 			],
# 			"category_id": 5,
# 			"area": 94.44444444444565,
# 			"is_crowd": 0,
# 			"id": 19
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				657.5,
# 				292.5,
# 				7.083333333333371,
# 				15.833333333333371
# 			],
# 			"category_id": 5,
# 			"area": 112.15277777777865,
# 			"is_crowd": 0,
# 			"id": 20
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				671.68458781362,
# 				293.9068100358423,
# 				6.4516129032258505,
# 				13.261648745519722
# 			],
# 			"category_id": 5,
# 			"area": 85.55902416464394,
# 			"is_crowd": 0,
# 			"id": 21
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				681.7204301075269,
# 				294.6236559139785,
# 				5.376344086021504,
# 				12.903225806451587
# 			],
# 			"category_id": 5,
# 			"area": 69.37218175511605,
# 			"is_crowd": 0,
# 			"id": 22
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				691.3978494623656,
# 				294.9820788530466,
# 				4.3010752688172715,
# 				12.903225806451644
# 			],
# 			"category_id": 5,
# 			"area": 55.49774540409396,
# 			"is_crowd": 0,
# 			"id": 23
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				699.6415770609319,
# 				294.6236559139785,
# 				5.017921146953427,
# 				11.111111111111086
# 			],
# 			"category_id": 5,
# 			"area": 55.7546794105935,
# 			"is_crowd": 0,
# 			"id": 24
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				708.1005586592179,
# 				294.1340782122905,
# 				5.307262569832346,
# 				11.452513966480469
# 			],
# 			"category_id": 5,
# 			"area": 60.78149870478397,
# 			"is_crowd": 0,
# 			"id": 25
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				716.4804469273743,
# 				293.29608938547483,
# 				3.3519553072626422,
# 				12.849162011173236
# 			],
# 			"category_id": 5,
# 			"area": 43.069816797229656,
# 			"is_crowd": 0,
# 			"id": 26
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0007_20160212_021909_N_CH1_Seoul_Sun_Frontback_Day_72054_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0007_20160212_021909_N_CH1_Seoul_Sun_Frontback_Day_72054.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				828.2758620689656,
# 				486.2068965517241,
# 				349.655172413793,
# 				113.10344827586216
# 			],
# 			"category_id": 10,
# 			"area": 39547.205707491106,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				675.2380952380952,
# 				246.66666666666663,
# 				191.90476190476193,
# 				29.047619047619065
# 			],
# 			"category_id": 9,
# 			"area": 5574.376417233564,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0005_20160212_014017_E_CH1_Seoul_Sun_Frontback_Day_36589_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0005_20160212_014017_E_CH1_Seoul_Sun_Frontback_Day_36589.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				780.4878048780488,
# 				24.43266171792153,
# 				54.72624798711763,
# 				134.31660186167082
# 			],
# 			"category_id": 2,
# 			"area": 7350.643662268742,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0006_20160212_025116_E_CH0_Seoul_Sun_Mainroad_Day_11016_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0006_20160212_025116_E_CH0_Seoul_Sun_Mainroad_Day_11016.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				179.76190476190476,
# 				450,
# 				138.09523809523813,
# 				19.047619047619037
# 			],
# 			"category_id": 10,
# 			"area": 2630.3854875283437,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				362.4113475177305,
# 				205.67375886524823,
# 				160.99290780141848,
# 				258.1560283687943
# 			],
# 			"category_id": 2,
# 			"area": 41561.28967355767,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0006_20160212_022109_E_CH1_Seoul_Sun_Frontback_Sunset_10006_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0006_20160212_022109_E_CH1_Seoul_Sun_Frontback_Sunset_10006.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				256.55172413793105,
# 				261.3793103448276,
# 				135.17241379310343,
# 				32.413793103448256
# 			],
# 			"category_id": 10,
# 			"area": 4381.45065398335,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				487.58620689655174,
# 				64.82758620689656,
# 				37.931034482758605,
# 				88.96551724137932
# 			],
# 			"category_id": 2,
# 			"area": 3374.5541022592142,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				548.2758620689656,
# 				62.06896551724138,
# 				30.34482758620686,
# 				89.6551724137931
# 			],
# 			"category_id": 2,
# 			"area": 2720.570749108201,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				961.3793103448276,
# 				188.9655172413793,
# 				88.27586206896535,
# 				79.31034482758622
# 			],
# 			"category_id": 6,
# 			"area": 7001.189060642081,
# 			"is_crowd": 0,
# 			"id": 4
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1207.1794871794873,
# 				157.94871794871796,
# 				60.512820512820326,
# 				89.74358974358975
# 			],
# 			"category_id": 3,
# 			"area": 5430.63773833003,
# 			"is_crowd": 0,
# 			"id": 5
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0008_20201210_134646_E_CH0_Seoul_Cloud_Frontback_Day_11898_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0008_20201210_134646_E_CH0_Seoul_Cloud_Frontback_Day_11898.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				431.1510700265924,
# 				179.10598961630998,
# 				55.10953526655692,
# 				191.26250474863875
# 			],
# 			"category_id": 2,
# 			"area": 10540.387750615117,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V1F_HY_0008_20160212_021452_N_CH0_Seoul_Snow_Mainroad_Day_76065_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V1F_HY_0008_20160212_021452_N_CH0_Seoul_Snow_Mainroad_Day_76065.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				300,
# 				294.11764705882354,
# 				20.320855614973254,
# 				19.07308377896612
# 			],
# 			"category_id": 3,
# 			"area": 387.58138160465893,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# ...
# 			"area": 4025.2981399799364,
# 			"is_crowd": 0,
# 			"id": 6
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				696.376811594203,
# 				271.49758454106285,
# 				35.99033816425117,
# 				87.43961352657004
# 			],
# 			"category_id": 5,
# 			"area": 3146.981259772687,
# 			"is_crowd": 0,
# 			"id": 7
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				542.512077294686,
# 				266.9082125603865,
# 				35.74879227053145,
# 				79.95169082125602
# 			],
# 			"category_id": 5,
# 			"area": 2858.176386846838,
# 			"is_crowd": 0,
# 			"id": 8
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				777.8008298755186,
# 				245.6431535269709,
# 				31.32780082987551,
# 				51.65975103734439
# 			],
# 			"category_id": 5,
# 			"area": 1618.3863914188798,
# 			"is_crowd": 0,
# 			"id": 9
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0629_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_71635_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0629_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_71635.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				0,
# 				282.30779071254955,
# 				12.434437763848022,
# 				23.48727133171292
# 			],
# 			"category_id": 5,
# 			"area": 292.0510136167961,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				70.4618139951388,
# 				252.37303313291545,
# 				23.02673659971856,
# 				35.00063963157223
# 			],
# 			"category_id": 5,
# 			"area": 805.9505096178841,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				119.27849558654216,
# 				278.6235128565946,
# 				27.171549187667907,
# 				30.39529231162851
# 			],
# 			"category_id": 5,
# 			"area": 825.8871801189582,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				214.1486503773826,
# 				250.5308942049379,
# 				21.64513240373546,
# 				31.77689650761161
# 			],
# 			"category_id": 5,
# 			"area": 687.8151322870523,
# 			"is_crowd": 0,
# 			"id": 4
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				260.6626583088141,
# 				274.9392350006396,
# 				23.02673659971856,
# 				35.92170909556097
# 			],
# 			"category_id": 5,
# 			"area": 827.1597335551969,
# 			"is_crowd": 0,
# 			"id": 5
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				322.37431239605985,
# 				248.2282205449661,
# 				22.10566713572979,
# 				33.6190354355891
# 			],
# 			"category_id": 5,
# 			"area": 743.1712067634371,
# 			"is_crowd": 0,
# 			"id": 6
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				355.9933478316489,
# 				272.63656134066775,
# 				23.02673659971856,
# 				36.38224382755533
# 			],
# 			"category_id": 5,
# 			"area": 837.764345523853,
# 			"is_crowd": 0,
# 			"id": 7
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0676_20210129_132349_E_CH1_Seoul_Sun_Industrialroads_Day_95658_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0676_20210129_132349_E_CH1_Seoul_Sun_Industrialroads_Day_95658.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1003.5,
# 				300.5,
# 				79,
# 				140
# 			],
# 			"category_id": 5,
# 			"area": 11060,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1081.5,
# 				316.5,
# 				102,
# 				173
# 			],
# 			"category_id": 5,
# 			"area": 17646,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0527_20210129_132649_E_CH1_Seoul_Sun_Industrialroads_Day_93366_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0527_20210129_132649_E_CH1_Seoul_Sun_Industrialroads_Day_93366.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				29.423076923076923,
# 				289.6153846153846,
# 				39.42307692307692,
# 				58.269230769230774
# 			],
# 			"category_id": 5,
# 			"area": 2297.152366863905,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				715.8836689038031,
# 				255.2572706935123,
# 				39.14988814317678,
# 				57.270693512304234
# 			],
# 			"category_id": 5,
# 			"area": 2242.141244888871,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0646_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_40822_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0646_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_40822.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1066.493083807974,
# 				616.0455655004068,
# 				134.87388120423088,
# 				45.30512611879578
# 			],
# 			"category_id": 8,
# 			"area": 6110.47819808916,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				8.230799566176582,
# 				276.2611559538564,
# 				37.18440862689557,
# 				56.705428850892986
# 			],
# 			"category_id": 5,
# 			"area": 2108.5578377549577,
# 			"is_crowd": 0,
# 			"id": 2
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0551_20210129_132449_E_CH1_Seoul_Sun_Industrialroads_Day_47705_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0551_20210129_132449_E_CH1_Seoul_Sun_Industrialroads_Day_47705.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1060.6194690265486,
# 				254.8672566371681,
# 				88.49557522123882,
# 				136.72566371681415
# 			],
# 			"category_id": 5,
# 			"area": 12099.61625812513,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				838.9261744966443,
# 				231.3199105145414,
# 				45.01911971281413,
# 				67.11409395973158
# 			],
# 			"category_id": 5,
# 			"area": 3021.417430390212,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				793.609022556391,
# 				224.24812030075188,
# 				34.77443609022555,
# 				51.87969924812026
# 			],
# 			"category_id": 5,
# 			"area": 1804.0872858838804,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				757.7067669172932,
# 				219.73684210526315,
# 				26.691729323308323,
# 				40.413533834586445
# 			],
# 			"category_id": 5,
# 			"area": 1078.7071061111442,
# 			"is_crowd": 0,
# 			"id": 4
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0626_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_79518_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0626_20210129_132849_E_CH1_Seoul_Sun_Industrialroads_Day_79518.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1020.12344775718,
# 				262.22617227727136,
# 				30.32513652289356,
# 				37.81837293695361
# 			],
# 			"category_id": 5,
# 			"area": 1146.8473223868211,
# 			"is_crowd": 0,
# 			"id": 1
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0633_20210129_132349_N_CH1_Seoul_Sun_Industrialroads_Day_13562_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0633_20210129_132349_N_CH1_Seoul_Sun_Industrialroads_Day_13562.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				269.1616489115331,
# 				415.00694766095415,
# 				108.49467345993514,
# 				20.15748031496059
# 			],
# 			"category_id": 10,
# 			"area": 2186.9792445467197,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				835.09451266113,
# 				228.9091557548275,
# 				17.608396596525267,
# 				25.760432057879456
# 			],
# 			"category_id": 5,
# 			"area": 453.599904172985,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				750.9655066999541,
# 				234.77862128700255,
# 				23.151780710246157,
# 				33.2603046823254
# 			],
# 			"category_id": 5,
# 			"area": 770.0352803611711,
# 			"is_crowd": 0,
# 			"id": 3
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				741.8352269832374,
# 				230.2134814286442,
# 				19.890966525704357,
# 				28.36908340551284
# 			],
# 			"category_id": 5,
# 			"area": 564.2884883839708,
# 			"is_crowd": 0,
# 			"id": 4
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				727.813725989708,
# 				220.10495745656493,
# 				16.63015234116267,
# 				23.477862128700252
# 			],
# 			"category_id": 5,
# 			"area": 390.4404238450989,
# 			"is_crowd": 0,
# 			"id": 5
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				424.88408824578386,
# 				227.930911499465,
# 				17.934478014979334,
# 				29.673409079329502
# 			],
# 			"category_id": 5,
# 			"area": 532.1771027627232,
# 			"is_crowd": 0,
# 			"id": 6
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				575.8597849900647,
# 				215.8658990166607,
# 				10.760686808987655,
# 				16.95623375961685
# 			],
# 			"category_id": 5,
# 			"area": 182.4607209472202,
# 			"is_crowd": 0,
# 			"id": 7
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }
# {
# 	"info": {
# 		"description": "V4F_HY_0687_20210129_132649_E_CH1_Seoul_Sun_Industrialroads_Day_73517_BBOX JSON file",
# 		"url": "",
# 		"version": "1.0",
# 		"year": 2021,
# 		"contributor": "Konkuk_university",
# 		"date_created": "2021/05/12"
# 	},
# 	"images": {
# 		"file_name": "V4F_HY_0687_20210129_132649_E_CH1_Seoul_Sun_Industrialroads_Day_73517.png",
# 		"height": 720,
# 		"width": 1280,
# 		"id": 1
# 	},
# 	"annotations": [
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				185.3449951409135,
# 				313.46938775510205,
# 				97.02623906705536,
# 				151.75898931000967
# 			],
# 			"category_id": 5,
# 			"area": 14724.603977367697,
# 			"is_crowd": 0,
# 			"id": 1
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				368.20213799805634,
# 				282.3712342079689,
# 				62.196307094266274,
# 				87.07482993197277
# 			],
# 			"category_id": 5,
# 			"area": 5415.732862629988,
# 			"is_crowd": 0,
# 			"id": 2
# 		},
# 		{
# 			"segmentation": [],
# 			"polyline": [],
# 			"image_id": 1,
# 			"bbox": [
# 				1037.4344023323615,
# 				309.73760932944606,
# 				111.9533527696792,
# 				175.39358600583083
# 			],
# 			"category_id": 5,
# 			"area": 19635.90000764985,
# 			"is_crowd": 0,
# 			"id": 3
# 		}
# 	],
# 	"categories": [
# 		{
# 			"id": 1,
# 			"name": "Animals(Dolls)"
# 		},
# 		{
# 			"id": 2,
# 			"name": "Person"
# 		},
# 		{
# 			"id": 3,
# 			"name": "Garbage bag & sacks"
# 		},
# 		{
# 			"id": 4,
# 			"name": "Construction signs & Parking prohibited board"
# 		},
# 		{
# 			"id": 5,
# 			"name": "Traffic cone"
# 		},
# 		{
# 			"id": 6,
# 			"name": "Box"
# 		},
# 		{
# 			"id": 7,
# 			"name": "Stones on road"
# 		},
# 		{
# 			"id": 8,
# 			"name": "Pothole on road"
# 		},
# 		{
# 			"id": 9,
# 			"name": "Filled pothole"
# 		},
# 		{
# 			"id": 10,
# 			"name": "Manhole"
# 		}
# 	]
# }

# %% [markdown]
# # 이미지 라벨링 출력

# %%
ex_img = cv2.imread(str(image / "V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522.png"))
with open(str(label/'V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522_BBOX.json')) as f:
    ex_label = json.load(f)
    box = ex_label['annotations'][0]['bbox']
print(box[0])

ff = np.fromfile('D:/Data/YOLO/Road_Obstacles/2020-02-061.도로장애물표면인지(수도권)_sample/061.도로장애물-표면인지영상(수도권)_샘플_원천데이터/V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522.png', np.uint8)
ex_img = cv2.imdecode(ff,cv2.IMREAD_COLOR) ##imread 한글 경로가 오류남 fromfile ->imdecode 로 처리
print(np.shape(ex_img)[0])
cv2.rectangle(ex_img,(int(box[0]),int(box[1]),int(box[2]),int(box[3])),(0,0,255), 1) ## 
cv2.imshow('ex_img',ex_img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 941.8590253825064
# 720

# %% [markdown]
# # 데이터 정제
# # 1. dataframe 작성

# %%
data_json = label.glob('*.json') ## glob 함수는 generator을 반환해 주는 거여서 data_json을 계속해서 초기화 시켜야함
df = pd.DataFrame({'file':[],
                       'class':[],
                       'center_x':[],
                       'center_y':[],
                       'width':[],
                       'height':[],
                       'img_width':[],
                       'img_height':[]})
box_size = []
for j in data_json:
    with open(str(j)) as f:
        json_data = json.load(f)
        box= json_data['annotations'][0]['bbox'] ## 이 데이터는 annotations를 list안에 dictionary 형태로 저장해둠 ->[0]을 통해 list 벗겨줌
        box_size.append(len(box))
        file_name = json_data['images']['file_name']
        class_num = json_data['annotations'][0]['category_id'] 
        center_x = box[0] 
        center_y = box[1]
        width = box[2]
        height = box[3]
        img_w=json_data['images']['width']
        img_h=json_data['images']['height']
        dic = {'file':file_name,'class':class_num,'center_x':center_x,'center_y':center_y,'width':width,'height':height,'img_width':img_w,'img_height':img_h}
        df = df.append(dic, ignore_index=True)
box_size.
# Out:
# [4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4]

# %% [markdown]
# # 데이터 시각화

# %%
fig, ax = plt.subplots(2,2,figsize = (15,15))
sns.boxplot(x = 'class', y='width',data=df, ax= ax[0][0])
sns.boxplot(x = 'class', y='height',data=df,ax= ax[0][1])
sns.boxplot(x = 'class', y='img_width',data=df, ax= ax[1][0])
sns.boxplot(x = 'class', y='img_height',data=df, ax= ax[1][1])
fig.tight_layout()
plt.show()

# %% [markdown]
# # 2. 결측치 확인

# %%
df.isnull().sum()
# Out:
# file          0
# class         0
# center_x      0
# center_y      0
# width         0
# height        0
# img_width     0
# img_height    0
# dtype: int64

# %% [markdown]
# # 3. 0 값 데이터 확인 및 삭제

# %%
df_zero = df.copy()
list1 = ['class', 'width', 'height','img_width', 'img_height']

for i in list1:
    df_zero = df_zero.drop(df_zero[df_zero[i]==0].index)
    df_zero=  df_zero.reset_index(drop=True)
    

df_zero.describe()
df.describe()
# Out:
#             class     center_x    center_y        width      height  \
# count  855.000000   855.000000  855.000000   855.000000  855.000000
# mean     6.118129   604.517102  317.578426   128.423745  114.021182
# std      3.299824   349.402373  183.516572    98.216526  106.299246
# min      1.000000     0.000000    0.000000     0.800000    0.800000
# 25%      2.000000   313.199088  201.410256    56.476572   39.792797
# 50%      5.000000   618.965517  298.091707   100.000000   76.296296
# 75%     10.000000   906.882739  464.294199   183.366021  153.682622
# max     10.000000  1237.695400  693.661972  1281.000000  720.000000
#
#          img_width  img_height
# count   855.000000  855.000000
# mean   1278.588304  719.157895
# std      43.778893   24.623480
# min       0.000000    0.000000
# 25%    1280.000000  720.000000
# 50%    1280.000000  720.000000
# 75%    1280.000000  720.000000
# max    1281.000000  720.000000

# %% [markdown]
# # 데이터 정제

# %%
df_refine = df_zero.copy()

for i in df_refine.index:
    w=df_refine.loc[i,'img_width']
    h=df_refine.loc[i,'img_height']
    df_refine = df_refine.astype({'class':'int'})
    df_refine.loc[i,'center_x'] = df_refine.loc[i,'center_x']/w
    df_refine.loc[i,'width'] = df_refine.loc[i,'width']/w
    df_refine.loc[i,'center_y'] = df_refine.loc[i,'center_y']/h
    df_refine.loc[i,'height'] = df_refine.loc[i,'height']/h
    
df_refine[df_refine['file']=='V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_Industrialroads_Day_07522.png']
# Out:
#                                                 file  class  center_x  \
# 1  V0F_HY_0093_20210129_133533_N_CH1_Seoul_Sun_In...      4  0.735827
#
#    center_y     width    height  img_width  img_height
# 1  0.380492  0.060582  0.242131     1280.0       720.0

# %% [markdown]
# # dataframe txt 파일로 저장

# %%
for i in df_refine.index:
    with open(txt/((df_refine.iloc[i,0][:-3])+'txt'), 'w') as f:
        for item in df_refine.iloc[i,1:6].tolist():
            f.write("%s " % item)
